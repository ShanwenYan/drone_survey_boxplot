# %%
library(dplyr)
library(readxl)
library(stringr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
Drone_Controller_Questionnaire <- read_excel("Drone-Controller-Questionnaire.xlsx", range = "D1:AG12")

Drone_Controller_Questionnaire

H <- colnames(Drone_Controller_Questionnaire)

H
# Out:
#    (JoyStick Controller) The Drone Controller was comfortable to use
# 1  5
# 2  3
# 3  5
# 4  3
# 5  5
# 6  4
# 7  2
# 8  4
# 9  4
# 10 4
# 11 5
#    (JoyStick Controller) The controller layout did not confuse me
# 1  5
# 2  3
# 3  5
# 4  4
# 5  5
# 6  4
# 7  3
# 8  4
# 9  4
# 10 5
# 11 5
#    (JoyStick Controller) I liked this interface for flying the drone
# 1  3
# 2  3
# 3  5
# 4  4
# 5  5
# 6  4
# 7  4
# 8  4
# 9  5
# 10 4
# 11 5
#    (JoyStick Controller) The controller to fly the drone felt natural to me
# 1  5
# 2  4
# 3  5
# 4  4
# 5  5
# 6  4
# 7  2
# 8  4
# 9  3
# 10 5
# 11 4
#    (JoyStick Controller) It was fun to use this interface to control the drone
# 1  4
# 2  3
# 3  5
# 4  4
# 5  5
# 6  5
# 7  4
# 8  4
# 9  5
# 10 3
# 11 4
#    (JoyStick Controller) I did not feel frustrated using the drone controller
# 1  4
# 2  4
# 3  5
# 4  3
# 5  4
# 6  4
# 7  3
# 8  3
# 9  4
# 10 4
# 11 5
#    (JoyStick Controller) I did not feel discomfort or pain while using this drone controller
# 1  4
# 2  4
# 3  5
# 4  4
# 5  5
# 6  4
# 7  5
# 8  5
# 9  5
# 10 5
# 11 5
#    (JoyStick Controller) It was easy to use this drone controller
# 1  5
# 2  3
# 3  5
# 4  4
# 5  5
# 6  4
# 7  2
# 8  4
# 9  3
# 10 5
# 11 5
#    (JoyStick Controller) The drone always flew in a predictable way
# 1  3
# 2  4
# 3  5
# 4  3
# 5  4
# 6  3
# 7  3
# 8  3
# 9  2
# 10 5
# 11 5
#    (JoyStick Controller) Task Completion time ⋯
# 1   70                                        ⋯
# 2   91                                        ⋯
# 3  109                                        ⋯
# 4  112                                        ⋯
# 5  109                                        ⋯
# 6   95                                        ⋯
# 7  102                                        ⋯
# 8  120                                        ⋯
# 9  115                                        ⋯
# 10 118                                        ⋯
# 11 121                                        ⋯
#    (VIVE Controller) The Drone Controller was comfortable to use
# 1  3
# 2  4
# 3  5
# 4  4
# 5  5
# 6  4
# 7  4
# 8  4
# 9  5
# 10 4
# 11 3
#    (VIVE Controller) The controller layout did not confuse me
# 1  3
# 2  5
# 3  5
# 4  5
# 5  5
# 6  4
# 7  3
# 8  4
# 9  4
# 10 4
# 11 2
#    (VIVE Controller) I liked this interface for flying the drone
# 1  3
# 2  4
# 3  5
# 4  3
# 5  4
# 6  5
# 7  4
# 8  4
# 9  5
# 10 3
# 11 2
#    (VIVE Controller) The controller to fly the drone felt natural to me
# 1  3
# 2  4
# 3  5
# 4  4
# 5  4
# 6  4
# 7  3
# 8  3
# 9  5
# 10 3
# 11 3
#    (VIVE Controller) It was fun to use this interface to control the drone
# 1  3
# 2  4
# 3  5
# 4  3
# 5  4
# 6  4
# 7  4
# 8  4
# 9  4
# 10 3
# 11 4
#    (VIVE Controller) I did not feel frustrated using the drone controller
# 1  2
# 2  5
# 3  5
# 4  4
# 5  4
# 6  5
# 7  3
# 8  4
# 9  5
# 10 2
# 11 2
#    (VIVE Controller) I did not feel discomfort or pain while using this drone controller
# 1  4
# 2  5
# 3  5
# 4  4
# 5  5
# 6  4
# 7  4
# 8  5
# 9  5
# 10 3
# 11 5
#    (VIVE Controller) It was easy to use this drone controller
# 1  2
# 2  4
# 3  5
# 4  4
# 5  5
# 6  4
# 7  4
# 8  4
# 9  5
# 10 3
# 11 2
#    (VIVE Controller) The drone always flew in a predictable way
# 1  3
# 2  4
# 3  5
# 4  4
# 5  4
# 6  3
# 7  4
# 8  4
# 9  4
# 10 2
# 11 2
#    (VIVE Controller) Task Completion time
# 1   91
# 2   69
# 3  108
# 4  146
# 5   92
# 6   89
# 7   73
# 8   69
# 9   76
# 10 104
# 11  91
#  [1] "(JoyStick Controller) The Drone Controller was comfortable to use"
#  [2] "(JoyStick Controller) The controller layout did not confuse me"
#  [3] "(JoyStick Controller) I liked this interface for flying the drone"
#  [4] "(JoyStick Controller) The controller to fly the drone felt natural to me"
#  [5] "(JoyStick Controller) It was fun to use this interface to control the drone"
#  [6] "(JoyStick Controller) I did not feel frustrated using the drone controller"
#  [7] "(JoyStick Controller) I did not feel discomfort or pain while using this drone controller"
#  [8] "(JoyStick Controller) It was easy to use this drone controller"
#  [9] "(JoyStick Controller) The drone always flew in a predictable way"
# [10] "(JoyStick Controller) Task Completion time"
# [11] "(VR Controller) The Drone Controller was comfortable to use"
# [12] "(VR Controller) The controller layout did not confuse me"
# [13] "(VR Controller) I liked this interface for flying the drone"
# [14] "(VR Controller) The controller to fly the drone felt natural to me"
# [15] "(VR Controller) It was fun to use this interface to control the drone"
# [16] "(VR Controller) I did not feel frustrated using the drone controller"
# [17] "(VR Controller) I did not feel discomfort or pain while using this drone controller"
# [18] "(VR Controller) It was easy to use this drone controller"
# [19] "(VR Controller) The drone always flew in a predictable way"
# [20] "(VR Controller) Task Completion time"
# [21] "(VIVE Controller) The Drone Controller was comfortable to use"
# [22] "(VIVE Controller) The controller layout did not confuse me"
# [23] "(VIVE Controller) I liked this interface for flying the drone"
# [24] "(VIVE Controller) The controller to fly the drone felt natural to me"
# [25] "(VIVE Controller) It was fun to use this interface to control the drone"
# [26] "(VIVE Controller) I did not feel frustrated using the drone controller"
# [27] "(VIVE Controller) I did not feel discomfort or pain while using this drone controller"
# [28] "(VIVE Controller) It was easy to use this drone controller"
# [29] "(VIVE Controller) The drone always flew in a predictable way"
# [30] "(VIVE Controller) Task Completion time"

# %%
Q1 <- str_detect(H,'comfortable')
Q2 <- str_detect(H,'layout') 
Q3 <- str_detect(H,'liked')
Q4 <- str_detect(H,'natural')
Q5 <- str_detect(H,'fun')
Q6 <- str_detect(H,'frustrated')
Q7 <- str_detect(H,'discomfort')
Q8 <- str_detect(H,'easy')
Q9 <- str_detect(H,'predictable')
Q10 <- str_detect(H,'Completion')

Q = array(c(Q1,Q2,Q3,Q4,Q5,Q6,Q7,Q8,Q9,Q10),dim = c(30,10))

# %%
par(mfrow=c(4,3))

for (i in 1:10){
  Drone_Controller_Questionnaire%>%
    select(H[Q[,i]])%>%
    boxplot(main = paste0('Q',i),col = c('red','green','blue'),names = c('JoyStick','VR','VIVE'))
}
# Out:
# Plot with title “Q10”
